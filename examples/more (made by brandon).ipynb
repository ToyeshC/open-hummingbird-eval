# %%
import pandas as pd

df = pd.read_csv('results_exp_b.csv')

# %%
df
# Out:
#         job_id        model  class_num train_bins  val_bin      jac0  \
# 0     11912061  dino_vits16         70    0_30_75        0  0.987960
# 1     11912061  dino_vits16         70    0_30_75       15  0.983525
# 2     11912061  dino_vits16         70    0_30_75       30  0.987285
# 3     11912061  dino_vits16         70    0_30_75       45  0.985443
# 4     11912061  dino_vits16         70    0_30_75       60  0.987786
# ...        ...          ...        ...        ...      ...       ...
# 3551  11944187         clip         99   15_75_90       30  0.934360
# 3552  11944187         clip         99   15_75_90       45  0.931616
# 3553  11944187         clip         99   15_75_90       60  0.924941
# 3554  11944187         clip         99   15_75_90       75  0.937282
# 3555  11944187         clip         99   15_75_90       90  0.946238
#
#           jac1  jac_mean
# 0     0.854220  0.921090
# 1     0.801261  0.892393
# 2     0.838755  0.913020
# 3     0.809547  0.897495
# ...

# %%
df = df[df['class_num'] == 99]
df = df[df['model'] == 'clip']


len(df)
# Out:
# 1778

# %%
new = df[df['train_bins'] == '0_30_75']

new['jac0'].mean()
# Out:
# 0.9634509947868336

# %%
df
# Out:
#         job_id        model  class_num train_bins  val_bin      jac0  \
# 889   11941002  dino_vits16         99    0_30_75        0  0.981313
# 890   11941002  dino_vits16         99    0_30_75       15  0.952411
# 891   11941002  dino_vits16         99    0_30_75       30  0.982018
# 892   11941002  dino_vits16         99    0_30_75       45  0.957667
# 893   11941002  dino_vits16         99    0_30_75       60  0.946273
# ...        ...          ...        ...        ...      ...       ...
# 1773  11941002  dino_vits16         99   15_75_90       30  0.947534
# 1774  11941002  dino_vits16         99   15_75_90       45  0.944769
# 1775  11941002  dino_vits16         99   15_75_90       60  0.939462
# 1776  11941002  dino_vits16         99   15_75_90       75  0.975126
# 1777  11941002  dino_vits16         99   15_75_90       90  0.977661
#
#           jac1  jac_mean
# 889   0.791476  0.886395
# 890   0.540679  0.746545
# 891   0.794478  0.888248
# 892   0.589596  0.773631
# ...

# %%
new
# Out:
#      job_id train_bins  val_bin      jac0      jac1  jac_mean
# 0  11912061    0_30_75        0  0.987960  0.854220  0.921090
# 1  11912061    0_30_75       15  0.983525  0.801261  0.892393
# 2  11912061    0_30_75       30  0.987285  0.838755  0.913020
# 3  11912061    0_30_75       45  0.985443  0.809547  0.897495
# 4  11912061    0_30_75       60  0.987786  0.830865  0.909326
# 5  11912061    0_30_75       75  0.989801  0.856557  0.923179
# 6  11912061    0_30_75       90  0.984459  0.793515  0.888987

# %%
df_filtered = df[~df['train_bins'].str.contains('0')]
df_filtered
# Out:
#        job_id train_bins  val_bin      jac0      jac1  jac_mean
# 210  11912061      15_45        0  0.983919  0.811692  0.897806
# 211  11912061      15_45       15  0.988030  0.855232  0.921631
# 212  11912061      15_45       30  0.983295  0.793317  0.888306
# 213  11912061      15_45       45  0.988716  0.852561  0.920639
# 214  11912061      15_45       60  0.987652  0.830914  0.909283
# 215  11912061      15_45       75  0.985998  0.807168  0.896583
# 216  11912061      15_45       90  0.983805  0.784666  0.884235
# 308  11912061      15_75        0  0.984400  0.816022  0.900211
# 309  11912061      15_75       15  0.987551  0.848873  0.918212
# 310  11912061      15_75       30  0.984136  0.801368  0.892752
# 311  11912061      15_75       45  0.985279  0.807836  0.896558
# 312  11912061      15_75       60  0.987629  0.829099  0.908364
# 313  11912061      15_75       75  0.989553  0.853375  0.921464
# 314  11912061      15_75       90  0.984382  0.793152  0.888767
# ...

# %%
df_filtered = df[
    (~df['train_bins'].str.contains('90')) &  # train_bins must NOT contain '0'
    (df['val_bin'] == 90)                     # val_bin must NOT be 0
]

df_filtered
# Out:
#        job_id     train_bins  val_bin      jac0      jac1  jac_mean
# 6    11912061        0_30_75       90  0.984459  0.793515  0.888987
# 13   11912061          15_30       90  0.983763  0.783991  0.883877
# 48   11912061  0_15_30_45_60       90  0.984590  0.793456  0.889023
# 62   11912061     0_30_45_75       90  0.984629  0.796315  0.890472
# 69   11912061        0_30_45       90  0.984307  0.789597  0.886952
# ..        ...            ...      ...       ...       ...       ...
# 797  11912061          30_75       90  0.984213  0.791795  0.888004
# 818  11912061           0_45       90  0.984186  0.788183  0.886184
# 825  11912061          60_75       90  0.984522  0.795207  0.889864
# 846  11912061       45_60_75       90  0.984648  0.796067  0.890358
# 874  11912061          30_45       90  0.984227  0.789364  0.886796
#
# [63 rows x 6 columns]

# %%
df_filtered = df[
    (~df['train_bins'].str.contains('75')) &  # train_bins must NOT contain '0'
    (df['val_bin'] == 75)                     # val_bin must NOT be 0
]

df_filtered

# df_filtered['jac1'].mean()

print('min jac0 :', df_filtered['jac0'].min())
print('max jac0 :', df_filtered['jac0'].max())
print('mean jac0 :', df_filtered['jac0'].mean())
print()
print('min jac1 :', df_filtered['jac1'].min())
print('max jac1 :', df_filtered['jac1'].max())
print('mean jac1 :', df_filtered['jac1'].mean())
# Out:
# min jac0 : 0.9845160437636548
# max jac0 : 0.9871930914642508
# mean jac0 : 0.9862022823139597
#
# min jac1 : 0.7903170232989734
# max jac1 : 0.8216522269261881
# mean jac1 : 0.8103053517852662

# %%
import matplotlib.pyplot as plt

p = df[df['train_bins'] == '0']
# Assuming p is your DataFrame
x = p['val_bin']
y = p['jac1']

plt.plot(x, y, marker='o')  # Optional: add markers
plt.xlabel('val_bin')
plt.ylabel('jac1')
plt.title('train bin : 0')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

p = df[df['train_bins'] == '15']
# Assuming p is your DataFrame
x = p['val_bin']
y = p['jac1']

plt.plot(x, y, marker='o')  # Optional: add markers
plt.xlabel('val_bin')
plt.ylabel('jac1')
plt.title('train bin : 15')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

p = df[df['train_bins'] == '30']
# Assuming p is your DataFrame
x = p['val_bin']
y = p['jac1']

plt.plot(x, y, marker='o')  # Optional: add markers
plt.xlabel('val_bin')
plt.ylabel('jac1')
plt.title('jac1 vs val_bin')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

p = df[df['train_bins'] == '45']
# Assuming p is your DataFrame
x = p['val_bin']
y = p['jac1']

plt.plot(x, y, marker='o')  # Optional: add markers
plt.xlabel('val_bin')
plt.ylabel('jac1')
plt.title('jac1 vs val_bin')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

p = df[df['train_bins'] == '60']
# Assuming p is your DataFrame
x = p['val_bin']
y = p['jac1']

plt.plot(x, y, marker='o')  # Optional: add markers
plt.xlabel('val_bin')
plt.ylabel('jac1')
plt.title('jac1 vs val_bin')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

p = df[df['train_bins'] == '75']
# Assuming p is your DataFrame
x = p['val_bin']
y = p['jac1']

plt.plot(x, y, marker='o')  # Optional: add markers
plt.xlabel('val_bin')
plt.ylabel('jac1')
plt.title('jac1 vs val_bin')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

p = df[df['train_bins'] == '90']
# Assuming p is your DataFrame
x = p['val_bin']
y = p['jac1']

plt.plot(x, y, marker='o')  # Optional: add markers
plt.xlabel('val_bin')
plt.ylabel('jac1')
plt.title('jac1 vs val_bin')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

p = df[df['train_bins'] == '0_15_30_45_60_75_90']
# Assuming p is your DataFrame
x = p['val_bin']
y = p['jac1']

plt.plot(x, y, marker='o')  # Optional: add markers
plt.xlabel('val_bin')
plt.ylabel('jac1')
plt.title('train : 0_15_30_45_60_75_90')
plt.grid(True)
plt.show()

# %%
p = p.drop_duplicates()
p
# Out:
#         job_id model  class_num           train_bins  val_bin      jac0  \
# 2492  11944187  clip         99  0_15_30_45_60_75_90        0  0.949915
# 2493  11944187  clip         99  0_15_30_45_60_75_90       15  0.943447
# 2494  11944187  clip         99  0_15_30_45_60_75_90       30  0.946889
# 2495  11944187  clip         99  0_15_30_45_60_75_90       45  0.951424
# 2496  11944187  clip         99  0_15_30_45_60_75_90       60  0.946432
# 2497  11944187  clip         99  0_15_30_45_60_75_90       75  0.936647
# 2498  11944187  clip         99  0_15_30_45_60_75_90       90  0.942754
# 2499  11944186  clip         99  0_15_30_45_60_75_90        0  0.949915
# 2500  11944186  clip         99  0_15_30_45_60_75_90       15  0.943447
# 2501  11944186  clip         99  0_15_30_45_60_75_90       30  0.946889
# 2502  11944186  clip         99  0_15_30_45_60_75_90       45  0.951424
# 2503  11944186  clip         99  0_15_30_45_60_75_90       60  0.946432
# ...

# %%
import matplotlib.pyplot as plt

p = df[df['train_bins'] == '15_30_45_60_75']
# Assuming p is your DataFrame
x = p['val_bin']
y = p['jac1']

pp = df[df['train_bins'] == '0_15_30_45_60_75_90']
# Assuming p is your DataFrame
x2 = pp['val_bin']
y2 = pp['jac1']

pp = df[df['train_bins'] == '30_45_60']
# Assuming p is your DataFrame
x3 = pp['val_bin']
y3 = pp['jac1']

plt.plot(x, y, marker='o')  # Optional: add markers
plt.plot(x2, y2, marker='x')  # Optional: add markers
plt.plot(x3, y3, marker='.')  # Optional: add markers

plt.xlabel('val_bin')
plt.ylabel('jac1')
plt.title('jac1 vs val_bin')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

p = df[df['train_bins'] == '0']
# Assuming p is your DataFrame
x = p['val_bin']
y = p['jac1']

pp = df[df['train_bins'] == '0_15']
# Assuming p is your DataFrame
x2 = pp['val_bin']
y2 = pp['jac1']

pp = df[df['train_bins'] == '0_15_30']
# Assuming p is your DataFrame
x3 = pp['val_bin']
y3 = pp['jac1']


pp = df[df['train_bins'] == '0_15_30_45']
# Assuming p is your DataFrame
x4 = pp['val_bin']
y4 = pp['jac1']

pp = df[df['train_bins'] == '0_15_30_45_60']
# Assuming p is your DataFrame
x5 = pp['val_bin']
y5 = pp['jac1']

pp = df[df['train_bins'] == '0_15_30_45_60_75']
# Assuming p is your DataFrame
x6 = pp['val_bin']
y6 = pp['jac1']

pp = df[df['train_bins'] == '0_15_30_45_60_75_90']
# Assuming p is your DataFrame
x7 = pp['val_bin']
y7 = pp['jac1']
 

plt.figure(dpi=100)
plt.plot(x, y, marker='o', label='0')  # Optional: add markers
plt.plot(x2, y2, marker='o', label='0_15')  # Optional: add markers
plt.plot(x3, y3, marker='o', label='0_15_30')  # Optional: add markers
plt.plot(x4, y4, marker='o', label='0_15_30_45' )  # Optional: add markers
plt.plot(x5, y5, marker='o', label='0_15_30_45_60')  # Optional: add markers
plt.plot(x6, y6, marker='o', label='0_15_30_45_60_75')  # Optional: add markers
plt.plot(x7, y7, marker='o', label='0_15_30_45_60_75_90')  # Optional: add markers
plt.legend()
plt.xlabel('val_bin')
plt.ylabel('jac1')
plt.title('pyriad start from 0')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

p = df[df['train_bins'] == '60']
# Assuming p is your DataFrame
x = p['val_bin']
y = p['jac1']

pp = df[df['train_bins'] == '60_75']
# Assuming p is your DataFrame
x2 = pp['val_bin']
y2 = pp['jac1']

pp = df[df['train_bins'] == '45_60_75']
# Assuming p is your DataFrame
x3 = pp['val_bin']
y3 = pp['jac1']


pp = df[df['train_bins'] == '30_45_60_75']
# Assuming p is your DataFrame
x4 = pp['val_bin']
y4 = pp['jac1']

pp = df[df['train_bins'] == '45_60_75_90']
# Assuming p is your DataFrame
x5 = pp['val_bin']
y5 = pp['jac1']

pp = df[df['train_bins'] == '30_45_60_75_90']
# Assuming p is your DataFrame
x6 = pp['val_bin']
y6 = pp['jac1']

pp = df[df['train_bins'] == '15_30_45_60_75_90']
# Assuming p is your DataFrame
x7 = pp['val_bin']
y7 = pp['jac1']
 

plt.figure(dpi=100)
plt.plot(x, y, marker='o', label='0')  # Optional: add markers
plt.plot(x2, y2, marker='o', label='0_15')  # Optional: add markers
plt.plot(x3, y3, marker='o', label='0_15_30')  # Optional: add markers
plt.plot(x4, y4, marker='o', label='0_15_30_45' )  # Optional: add markers
plt.plot(x5, y5, marker='o', label='0_15_30_45_60')  # Optional: add markers
plt.plot(x6, y6, marker='o', label='0_15_30_45_60_75')  # Optional: add markers
plt.plot(x7, y7, marker='o', label='0_15_30_45_60_75_90')  # Optional: add markers
plt.legend()
plt.xlabel('val_bin')
plt.ylabel('jac1')
plt.title('jac1 vs val_bin')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

p = df[df['train_bins'] == '0'][:7]
# Assuming p is your DataFrame
x = p['val_bin']
y = p['jac1']

pp = df[df['train_bins'] == '15'][:7]
# Assuming p is your DataFrame
x2 = pp['val_bin']
y2 = pp['jac1']

pp = df[df['train_bins'] == '30'][:7]
# Assuming p is your DataFrame
x3 = pp['val_bin']
y3 = pp['jac1']


pp = df[df['train_bins'] == '45'][:7]
# Assuming p is your DataFrame
x4 = pp['val_bin']
y4 = pp['jac1']

pp = df[df['train_bins'] == '60'][:7]
# Assuming p is your DataFrame
x5 = pp['val_bin']
y5 = pp['jac1']

pp = df[df['train_bins'] == '75'][:7]
# Assuming p is your DataFrame
x6 = pp['val_bin']
y6 = pp['jac1']

pp = df[df['train_bins'] == '90'][:7]
# Assuming p is your DataFrame
x7 = pp['val_bin']
y7 = pp['jac1']

# pp = df[df['train_bins'] == '75']
# # Assuming p is your DataFrame
# x8 = pp['val_bin']
# y8 = pp['jac1']

plt.figure(dpi=100)
plt.plot(x, y, marker='o', label='0')  # Optional: add markers
plt.plot(x2, y2, marker='o', label='15')  # Optional: add markers
plt.plot(x3, y3, marker='o', label='30')  # Optional: add markers
plt.plot(x4, y4, marker='o', label='45' )  # Optional: add markers
plt.plot(x5, y5, marker='o', label='60')  # Optional: add markers
plt.plot(x6, y6, marker='o', label='75')  # Optional: add markers
plt.plot(x7, y7, marker='o', label='90')  # Optional: add markers
# plt.plot(x8, y8, marker='o', label='0_15_30_45_60_75_90')  # Optional: add markers

plt.legend()
plt.xlabel('val_bin')
plt.ylabel('jac1')
plt.title('Train bin equals legend (only observed first 7 points)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

p = df[df['train_bins'] == '0']
# Assuming p is your DataFrame
x = p['val_bin']
y = p['jac1']

pp = df[df['train_bins'] == '0_15']
# Assuming p is your DataFrame
x2 = pp['val_bin']
y2 = pp['jac1']

pp = df[df['train_bins'] == '0_30']
# Assuming p is your DataFrame
x3 = pp['val_bin']
y3 = pp['jac1']


pp = df[df['train_bins'] == '0_45']
# Assuming p is your DataFrame
x4 = pp['val_bin']
y4 = pp['jac1']

pp = df[df['train_bins'] == '0_60']
# Assuming p is your DataFrame
x5 = pp['val_bin']
y5 = pp['jac1']

pp = df[df['train_bins'] == '0_75']
# Assuming p is your DataFrame
x6 = pp['val_bin']
y6 = pp['jac1']

pp = df[df['train_bins'] == '0_90']
# Assuming p is your DataFrame
x7 = pp['val_bin']
y7 = pp['jac1']

# pp = df[df['train_bins'] == '75']
# # Assuming p is your DataFrame
# x8 = pp['val_bin']
# y8 = pp['jac1']

plt.figure(dpi=100)
plt.plot(x, y, marker='o', label='0')  # Optional: add markers
plt.plot(x2, y2, marker='o', label='15')  # Optional: add markers
plt.plot(x3, y3, marker='o', label='30')  # Optional: add markers
plt.plot(x4, y4, marker='o', label='45' )  # Optional: add markers
plt.plot(x5, y5, marker='o', label='60')  # Optional: add markers
plt.plot(x6, y6, marker='o', label='75')  # Optional: add markers
plt.plot(x7, y7, marker='o', label='90')  # Optional: add markers
# plt.plot(x8, y8, marker='o', label='0_15_30_45_60_75_90')  # Optional: add markers

plt.legend()
plt.xlabel('val_bin')
plt.ylabel('jac1')
plt.title('jac1 vs val_bin')
plt.grid(True)
plt.show()

# %%
df_filtered = df[
    (df['train_bins'].str.contains('75')) &  # train_bins must NOT contain '0'
    (df['val_bin'] == 75)                     # val_bin must NOT be 0
]

df_filtered

# df_filtered['jac1'].mean()

print('min jac0 :', df_filtered['jac0'].min())
print('max jac0 :', df_filtered['jac0'].max())
print('mean jac0 :', df_filtered['jac0'].mean())
print()
print('min jac1 :', df_filtered['jac1'].min())
print('max jac1 :', df_filtered['jac1'].max())
print('mean jac1 :', df_filtered['jac1'].mean())
# Out:
# min jac0 : 0.9888827903076954
# max jac0 : 0.9899666327635256
# mean jac0 : 0.9895971450411243
#
# min jac1 : 0.8458773348764012
# max jac1 : 0.8594845478955582
# mean jac1 : 0.8542599515832812

# %%
df_filtered = df[
    (df['train_bins'].str.contains('90')) &  # train_bins must NOT contain '0'
    (df['val_bin'] == 90)                     # val_bin must NOT be 0
]

df_filtered

# df_filtered['jac1'].mean()

print('min jac0 :', df_filtered['jac0'].min())
print('max jac0 :', df_filtered['jac0'].max())
print('mean jac0 :', df_filtered['jac0'].mean())
print()
print('min jac1 :', df_filtered['jac1'].min())
print('max jac1 :', df_filtered['jac1'].max())
print('mean jac1 :', df_filtered['jac1'].mean())
# Out:
# min jac0 : 0.9879249714636282
# max jac0 : 0.9895618769240562
# mean jac0 : 0.9888586557200195
#
# min jac1 : 0.8375321719759952
# max jac1 : 0.859922616516162
# mean jac1 : 0.8506871121702981

# %%
# df_filtered['jac1'].mean()

print('min jac0 :', df_filtered['jac0'].min())
print('max jac0 :', df_filtered['jac0'].max())
print('mean jac0 :', df_filtered['jac0'].mean())
print()
print('min jac1 :', df_filtered['jac1'].min())
print('max jac1 :', df_filtered['jac1'].max())
print('mean jac1 :', df_filtered['jac1'].mean())
# Out:
# min jac0 : 0.9879249714636282
# max jac0 : 0.9895618769240562
# mean jac0 : 0.9888586557200195
#
# min jac1 : 0.8375321719759952
# max jac1 : 0.859922616516162
# mean jac1 : 0.8506871121702981

# %%
print('min jac0 :', df['jac0'].min())
print('max jac0 :', df['jac0'].max())
print('mean jac0 :', df['jac0'].mean())
print()
print('min jac1 :', df['jac1'].min())
print('max jac1 :', df['jac1'].max())
print('mean jac1 :', df['jac1'].mean())
# Out:
# min jac0 : 0.9802266348658422
# max jac0 : 0.9907154469754572
# mean jac0 : 0.986789580793935
#
# min jac1 : 0.7680765832288924
# max jac1 : 0.8701389670570658
# mean jac1 : 0.8298094636726758

# %%
print('min jac0 :', round(df['jac0'].min(), 3))
print('max jac0 :',  round(df['jac0'].max(), 3))
print('mean jac0 :',  round(df['jac0'].mean(), 3))
print()
print('min jac1 :',  round(df['jac1'].min(), 2))
print('max jac1 :',  round(df['jac1'].max(), 2))
print('mean jac1 :',  round(df['jac1'].mean(), 2))
# Out:
# min jac0 : 0.98
# max jac0 : 0.991
# mean jac0 : 0.987
#
# min jac1 : 0.77
# max jac1 : 0.87
# mean jac1 : 0.83

# %%
max_row = df.loc[df['jac1'].idxmax()]
val_bin = max_row['val_bin']
train_bin = max_row['train_bins']
jac1 = max_row['jac1']

train_bin
# Out:
# '15_30_45_60_75'

# %%
len(df['train_bins'].unique())
# Out:
# 127

# %%
new['jac1'].mean()
# Out:
# np.float64(0.8263883146416161)
